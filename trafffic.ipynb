# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sd_roads = pd.read_csv('data/sd_roads.csv')
sd_roads
# Out:
#         OBJECTID                ROADNAME  SURFACE_WIDTH  \
# 0              1                 443 AVE             22
# 1              2        KNUCKLEDUSTER RD             30
# 2              4            N EUCLID AVE             32
# 3              5                  142 ST             16
# 4              6                 415 AVE             24
# ...          ...                     ...            ...
# 149056    202581          JACKRABBIT AVE             14
# 149057    202582         UNIVERSITY BLVD             18
# 149058    202583         UNIVERSITY BLVD             18
# 149059    202586          JACKRABBIT AVE             18
# 149060    202976  BERRY PINES HEIGHTS DR             14
#
#                       SURFACE_TYPE TOTAL_LANES THROUGH_LANES  \
# 0       5 - Gravel or Crushed Rock     2 Lanes       2 Lanes
# 1                   8 - Bituminous     2 Lanes       2 Lanes
# 2                   8 - Bituminous     2 Lanes       2 Lanes
# ...

# %%
sd_roads.hist(column='SURFACE_WIDTH')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C369B88>]],
#       dtype=object)

# %%
surface_types = sd_roads.groupby(['SURFACE_TYPE']).count()
surface_types = surface_types['OBJECTID']
surface_types.plot.bar(title='Surface Types')
